# %% [markdown]
# # Day 1 - Lab 2: Generating a Product Requirements Document (PRD)
#
# **Objective:** Use the structured `day1_user_stories.json` artifact from the previous lab to generate a formal, comprehensive Product Requirements Document (PRD) in markdown format.
#
# **Estimated Time:** 60 minutes
#
# **Introduction:**
# With a validated set of user stories, we can now create a higher-level planning document: the PRD. A PRD serves as the source of truth for the product team, outlining the project's purpose, features, and requirements. In this lab, you will use an LLM to synthesize the detailed user stories into this formal document.
#
# For definitions of key terms used in this lab, please refer to the [GLOSSARY.md](../../GLOSSARY.md).

# %% [markdown]
# ## Step 1: Setup
#
# This initial block sets up our environment. It adds the project's root directory to the Python path, allowing us to import our custom `utils.py` script. We then initialize the connection to our Large Language Model (LLM) and load the JSON artifact from the previous lab.
#
# **Model Selection:**
# You can change the `model_name` parameter in the `setup_llm_client()` function to any of the models listed in `utils.py`, such as `"gemini-2.5-flash"` or `"meta-llama/Llama-3.3-70B-Instruct"`.
#
# **Helper Functions Used:**
# - `setup_llm_client()`: To configure the API client.
# - `get_completion()`: To send prompts to the LLM.
# - `load_artifact()`: To read the user stories JSON file and the PRD template.
# - `save_artifact()`: To save our generated PRD and Pydantic model.

# %%
import sys
import os
import json

# Add the project's root directory to the Python path to ensure 'utils' can be imported.
try:
    # Assumes the notebook is in 'labs/Day_01_.../'
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
except IndexError:
    # Fallback for different execution environments
    project_root = os.path.abspath(os.path.join(os.getcwd()))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from utils import setup_llm_client, get_completion, save_artifact, load_artifact, prompt_enhancer

# Initialize the LLM client. You can change the model here.
client, model_name, api_provider = setup_llm_client(model_name="gemini-2.5-pro")

# Load the artifact from Lab 1
user_stories_data = load_artifact("day1_user_stories.json")
# if user_stories_str:
#     user_stories_data = json.loads(user_stories_str)
# else:
#     user_stories_data = []
# Out:
# 2025-10-28 14:06:48,588 ag_aisoftdev.utils INFO LLM Client configured provider=google model=gemini-2.5-pro latency_ms=None artifacts_path=None

# %% [markdown]
# ## Step 2: The Challenges

# %% [markdown]
# ### Challenge 1 (Foundational): Generating a Simple PRD
#
# **Task:** Use the loaded user stories to generate a simple PRD.
#
# **Instructions:**
# 1. Create a prompt that instructs the LLM to act as a Product Manager.
# 2. Provide the `user_stories_data` as context.
# 3. Ask the LLM to generate a PRD with three sections: "Introduction", "User Personas", and "Features / User Stories".
#
# **Expected Quality:** A clean markdown document that correctly summarizes the provided user stories into the requested sections.

# %%
# TODO: Write a prompt to generate a simple PRD.
simple_prd_prompt = f"""
Write a simple Product Requirements Document (PRD) based on the following user stories:{user_stories_data}
"""
enhanced_prd_prompt = prompt_enhancer(simple_prd_prompt)

print("--- Generating Simple PRD ---")
if user_stories_data:
    simple_prd_output = get_completion(simple_prd_prompt, client, model_name, api_provider)
    print(simple_prd_output)
else:
    print("Skipping PRD generation because user stories are missing.")
# Out:
# 2025-10-28 14:06:49,222 ag_aisoftdev.utils INFO LLM Client configured provider=openai model=o3 latency_ms=None artifacts_path=None
# --- Generating Simple PRD ---
# Of course. Here is a simple Product Requirements Document (PRD) based on the user stories provided.
#
# ---
#
# ## **Product Requirements Document: Project OnboardFlow**
#
# *   **Version:** 1.0
# *   **Date:** October 26, 2023
# *   **Status:** Draft
# *   **Author:** Product Management
#
# ### 1. Introduction & Problem Statement
#
# Our current employee onboarding process is manual, inconsistent, and often leaves new hires feeling unprepared and managers overwhelmed. This leads to decreased productivity in the first few months, a disjointed new hire experience (especially for remote employees), and significant administrative overhead for managers, HR, and IT.
#
# **Project OnboardFlow** is a unified platform designed to automate, personalize, and streamline the onboarding experience from the moment an offer is signed through the first 90 days. It will provide a structured, engaging, and efficient journey for new hires while giving managers the visibility and tools they need to be effective coaches.
#
# ### 2. Goals & Objectives
#
# *   **Streamline Operations:** Reduce the manual administrative work for managers and support teams by at least 40%.
# *   **Enhance New Hire Experience:** Improve new hire satisfaction scores by 25% within the first six months of launch.
# *   **Accelerate Time-to-Productivity:** Decrease the average time for a new hire to become fully productive in their role by 20%.
#
# ### 3. User Personas
#
# *   **Maria the Hybrid Manager:** Needs efficiency, visibility, and tools to track progress and set clear expectations for her new hires without getting bogged down in manual follow-up.
# *   **Ben the On-site Sales Rep:** A new hire who wants clarity, structure, and social connections to feel prepared and reduce first-day anxiety.
# *   **Priya the Remote Engineer:** A new hire who needs access to information, clear learning paths, and ways to build virtual connections to feel included and become productive quickly.
#
# ### 4. Features & Requirements
#
# This section details the user stories and acceptance criteria for the core features of OnboardFlow, grouped by theme.
#
# #### **Theme 1: Pre-boarding & Day 1 Readiness**
#
# *   **Feature:** Onboarding Journey Orchestrator
#     *   **ID:** 1
#     *   **Priority:** High
#     *   **User Story:** As a new manager, I want an automated workflow to assign and track pre-boarding tasks so that I can ensure my new hire has everything they need on Day 1 without manual follow-up.
#     *   **Acceptance Criteria:**
#         *   When a new hire is added, tasks are automatically created in Jira for IT, HR, and the hiring manager.
#         *   I can view the status (To Do, In Progress, Done) of all pre-boarding tasks for my new hire.
#         *   The system sends reminders for overdue tasks.
#
# *   **Feature:** Personalized Pre-boarding Portal
#     *   **ID:** 2
#     *   **Priority:** High
#     *   **User Story:** As a new sales rep, I want a personalized portal to complete paperwork and see my schedule before I start so that I can feel prepared and reduce first-day administrative tasks.
#     *   **Acceptance Criteria:**
#         *   I can securely log in to the portal using a link from my offer letter.
#         *   I can complete and electronically sign all required HR documents.
#         *   The portal displays my Day 1 schedule, including times and locations.
#
# *   **Feature:** Dynamic Day 1 Agenda
#     *   **ID:** 4
#     *   **Priority:** High
#     *   **User Story:** As a new hire, I want a dynamic agenda for my first day integrated with my calendar so that I know exactly where to be and what to expect, which reduces my anxiety.
#     *   **Acceptance Criteria:**
#         *   My Day 1 schedule is automatically added to my Google Calendar.
#         *   Each calendar event includes a meeting link or physical location.
#         *   The agenda includes objectives for key meetings.
#
# #### **Theme 2: Connection & Culture**
#
# *   **Feature:** Meet Your Team Showcase
#     *   **ID:** 3
#     *   **Priority:** Medium
#     *   **User Story:** As a remote engineer, I want to see profiles of my new team members before I start so that I can put faces to names and make virtual introductions less awkward.
#     *   **Acceptance Criteria:**
#         *   The showcase displays photos, roles, and a fun fact for each team member.
#         *   I can click on a team member's profile to see a link to their LinkedIn.
#         *   The page clearly identifies my direct manager and assigned buddy.
#
# *   **Feature:** Automated Welcome Announcement
#     *   **ID:** 5
#     *   **Priority:** Medium
#     *   **User Story:** As a remote engineer, I want an automated welcome announcement posted in a public channel so that the wider company knows I've joined and I feel included from day one.
#     *   **Acceptance Criteria:**
#         *   A welcome message is automatically posted to a designated Slack channel on the morning of my start date.
#         *   The message includes my name, photo, role, and a fun fact I provided.
#         *   My manager is tagged in the welcome post.
#
# *   **Feature:** Onboarding Buddy Connector
#     *   **ID:** 6
#     *   **Priority:** High
#     *   **User Story:** As a new sales rep, I want to be automatically connected with a peer 'buddy' so that I have a go-to person for informal questions and can start building my network.
#     *   **Acceptance Criteria:**
#         *   The system assigns me a buddy from my department.
#         *   An automated Slack DM is sent to both me and my buddy with an introduction.
#         *   The introductory message includes conversation starters and a prompt to schedule a coffee chat.
#
# *   **Feature:** Interactive Org Chart
#     *   **ID:** 8
#     *   **Priority:** Medium
#     *   **User Story:** As a new sales rep, I want a searchable, interactive org chart so that I can quickly figure out who's who and find the right person to talk to in other departments.
#     *   **Acceptance Criteria:**
#         *   I can search for employees by name, title, or team.
#         *   Clicking on a profile shows their manager, direct reports, and team responsibilities.
#         *   The chart visually represents the company's reporting structure.
#
# *   **Feature:** Early Wins Recognition Feed
#     *   **ID:** 14
#     *   **Priority:** Low
#     *   **User Story:** As a remote engineer, I want a simple way for my manager and peers to give me public 'shout-outs' so that my contributions are visible and I feel valued early on.
#     *   **Acceptance Criteria:**
#         *   Users can give a shout-out using a Slack command (e.g., `/shoutout @Priya for fixing that bug`).
#         *   Shout-outs are posted in a public 'wins' channel.
#         *   All shout-outs I receive are collected on my profile within the onboarding tool.
#
# #### **Theme 3: Learning & Productivity**
#
# *   **Feature:** Role-Based Learning Pathways
#     *   **ID:** 7
#     *   **Priority:** High
#     *   **User Story:** As a remote engineer, I want a 90-day learning pathway specific to my role so that I have a clear, actionable roadmap to understand the codebase and become productive quickly.
#     *   **Acceptance Criteria:**
#         *   My pathway is pre-populated with tasks and learning modules for a Backend Engineer.
#         *   I can check off items as I complete them and see my overall progress.
#         *   The pathway includes links to key technical documentation and our LMS.
#
# *   **Feature:** Centralized Knowledge Hub
#     *   **ID:** 9
#     *   **Priority:** High
#     *   **User Story:** As a remote engineer, I want a centralized, searchable knowledge hub so that I can independently find answers to my questions about technical standards and internal tools.
#     *   **Acceptance Criteria:**
#         *   The hub has a prominent search bar that returns relevant documents and FAQs.
#         *   Content is categorized by department (e.g., Engineering, IT, HR).
#         *   The hub contains essential documents like 'How to set up your dev environment'.
#
# *   **Feature:** 30/60/90-Day Goal Tracker
#     *   **ID:** 11
#     *   **Priority:** High
#     *   **User Story:** As a manager, I want a simple framework to collaboratively set and track 30/60/90-day goals with my new hire so that we can align on expectations and have a clear definition of success.
#     *   **Acceptance Criteria:**
#         *   I can create 3-5 key goals for the onboarding period within the tool.
#         *   Both the new hire and I can add comments to track progress on each goal.
#         *   Goals can be marked as 'On Track', 'At Risk', or 'Complete'.
#
# *   **Feature:** Company Acronym Wiki
#     *   **ID:** 10
#     *   **Priority:** Low
#     *   **User Story:** As a new hire, I want a searchable wiki of company acronyms so that I can understand internal jargon and get up to speed faster in meetings.
#     *   **Acceptance Criteria:**
#         *   I can search for an acronym and see its full name and definition.
#         *   The wiki is user-editable, allowing employees to add new terms.
#         *   The wiki is linked from the Centralized Knowledge Hub.
#
# #### **Theme 4: Manager Enablement & Feedback**
#
# *   **Feature:** Manager Onboarding Dashboard
#     *   **ID:** 12
#     *   **Priority:** High
#     *   **User Story:** As a manager, I want a single dashboard to track the progress of all my new hires so that I can efficiently support them and identify potential issues early.
#     *   **Acceptance Criteria:**
#         *   The dashboard lists all my current new hires.
#         *   For each new hire, I can see their percentage completion of their learning pathway.
#         *   The dashboard flags upcoming or overdue check-ins.
#
# *   **Feature:** New Hire Pulse Surveys
#     *   **ID:** 13
#     *   **Priority:** Medium
#     *   **User Story:** As a new hire, I want to receive short, automated surveys so that I can provide confidential feedback on my onboarding experience and feel that my voice is heard.
#     *   **Acceptance Criteria:**
#         *   A short survey is automatically sent to me via Slack at the 30, 60, and 90-day marks.
#         *   The survey contains 2-3 questions about my experience.
#         *   My responses are submitted anonymously to HR for process improvement.
#
# ### 5. Out of Scope
#
# *   Full-fledged performance management system (beyond 90-day goal tracking).
# *   Payroll, benefits, and compensation management.
# *   Building a native task management or chat application (we will integrate with Jira and Slack).
# *   A native mobile application (for V1).
#
# ### 6. Assumptions & Dependencies
#
# *   **Dependencies:**
#     *   Access to stable APIs for Jira, Slack, and Google Calendar.
#     *   Access to an HRIS API to pull new hire data (name, role, manager, start date).
#     *   Availability of an e-signature service provider API.
# *   **Assumptions:**
#     *   HR, IT, and hiring managers will collaborate to create standardized task templates for the Onboarding Journey Orchestrator.
#     *   Content for the Knowledge Hub and Learning Pathways will be provided by department heads.
#
# ### 7. Success Metrics
#
# *   **New Hire Satisfaction Score:** Measured via the New Hire Pulse Surveys. Target: >8/10 average.
# *   **Learning Pathway Completion Rate:** Percentage of new hires who complete 90% of their learning pathway within 90 days. Target: 85%.
# *   **Manager Feedback:** Qualitative feedback from managers on time saved and ease of use.
# *   **First 90-Day Retention:** A decrease in voluntary employee turnover within the first 90 days.

# %% [markdown]
# ### Challenge 2 (Intermediate): Generating a PRD from a Template
#
# **Task:** Instead of just listing sections, we will now provide the LLM with a formal template to ensure the PRD's structure is consistent and complete.
#
# **Instructions:**
# 1. First, load the contents of `templates/prd_template.md` into a variable.
# 2. Create a new prompt that instructs the LLM to act as a Senior Product Manager.
# 3. Provide both the `user_stories_data` and the `prd_template_content` as context.
# 4. Instruct the LLM to populate the template with the information from the user stories, ensuring every section of the template is filled out.
#
# > **Tip:** The template has sections like 'Success Metrics' and 'Out of Scope' that aren't in the user stories. This is your chance to guide the LLM's creativity! Instruct it to infer logical content for these sections based on the project's overall goal.
#
# **Expected Quality:** A complete PRD that strictly follows the structure of the provided template file, demonstrating the LLM's ability to perform structured content generation.

# %%
# Load the PRD template
prd_template_content = load_artifact("templates/prd_template.md")

# TODO: Write a prompt to populate the PRD template.
template_prd_prompt = f"""
Act as a Senior Product Manager. Using the following user stories, populate the provided PRD template.
User Stories: {user_stories_data}
PRD Template:{prd_template_content}
"""

print("--- Generating PRD from Template ---")
if user_stories_data and prd_template_content:
    prd_from_template_output = get_completion(template_prd_prompt, client, model_name, api_provider)
    print(prd_from_template_output)
else:
    print("Skipping PRD generation because user stories or template are missing.")
    prd_from_template_output = ""
# Out:
# --- Generating PRD from Template ---
# Of course. As a Senior Product Manager, I've synthesized the provided user stories into a comprehensive Product Requirements Document. Here is the populated template.
#
# ***
#
# # Product Requirements Document: Project Ignition: The New Hire Onboarding Platform
#
# | Status | **Draft** |
# | :--- | :--- |
# | **Author** | Senior Product Manager |
# | **Version** | 1.0 |
# | **Last Updated** | October 26, 2023 |
#
# ## 1. Executive Summary & Vision
# *A high-level overview for stakeholders. What is this product, why are we building it, and what is the ultimate vision for its success?*
#
# Project Ignition is a centralized, automated platform designed to streamline and enrich the new hire onboarding experience. We are building this to solve the current fragmented and manual onboarding process, which leads to administrative overhead, new hire anxiety, and delayed productivity. The platform will serve new hires, their managers, and internal support teams like HR and IT.
#
# Our vision is to create a world-class onboarding journey that makes every new employee feel welcomed, prepared, and empowered to do their best work from day one, ultimately accelerating their integration and long-term success at the company.
#
# ## 2. The Problem
# *A detailed look at the pain points this product will solve. This section justifies the project's existence.*
#
# **2.1. Problem Statement:**
# New hires currently face a disjointed and overwhelming onboarding experience, characterized by manual paperwork, unclear expectations, and difficulty navigating the organization. This results in decreased initial productivity, a high volume of repetitive questions for managers and HR, and a risk of poor first impressions that can impact long-term retention. Managers lack a centralized way to track progress, and remote employees feel particularly disconnected from their teams and the company culture.
#
# **2.2. User Personas & Scenarios:**
#
# - **Persona 1: The New Hire (e.g., Ben the Sales Rep, Priya the Engineer)**
#     - **Scenario:** Priya, a remote engineer, is starting next week. She's anxious about her first day, unsure of her schedule, and doesn't know anyone on her team. She has to fill out a dozen PDF forms and has no clear roadmap for how she'll learn the complex codebase, making her feel isolated and unprepared.
#
# - **Persona 2: The Hiring Manager (e.g., Maria the Hybrid Manager)**
#     - **Scenario:** Maria has a new employee starting in two weeks. She spends hours manually creating a list of tasks, emailing IT to set up accounts, and chasing HR for paperwork status. She has no single view to confirm if the new hire's laptop has been shipped or if they have access to key systems, creating a stressful pre-boarding period and risking a poor Day 1 experience.
#
# - **Persona 3: The HR/IT Coordinator (Inferred)**
#     - **Scenario:** With every new hire, the HR team answers the same set of questions about benefits and policies. The IT team fields multiple tickets for standard software access. This repetitive, low-value work consumes significant time that could be spent on more strategic initiatives.
#
# ## 3. Goals & Success Metrics
# *How will we measure success? This section defines the specific, measurable outcomes we expect.*
#
# | Goal | Key Performance Indicator (KPI) | Target |
# | :--- | :--- | :--- |
# | Accelerate New Hire Productivity | Reduce time-to-first-contribution | Decrease by 25% within 6 months |
# | Reduce Administrative Overhead | Decrease in onboarding-related support tickets for HR/IT | 40% reduction in repetitive tickets |
# | Increase New Hire Engagement & Satisfaction | New Hire Satisfaction Score (eNPS) at 90 days | Achieve a score of +50 |
# | Improve Onboarding Consistency | Onboarding pathway completion rate | Achieve 95% completion rate for all tasks |
#
# ## 4. Functional Requirements & User Stories
# *The core of the PRD. This section details what the product must do, broken down into actionable user stories.*
#
# ---
# **Epic 1: Pre-boarding & Day 1 Readiness**
# *Ensuring new hires and the company are fully prepared for a successful start.*
#
# *   **Story ID 2 (High):** As a new sales rep, I want a personalized portal to complete paperwork and see my schedule before I start so that I can feel prepared and reduce first-day administrative tasks.
#     *   **Acceptance Criteria:**
#         *   I can securely log in to the portal using a link from my offer letter.
#         *   I can complete and electronically sign all required HR documents.
#         *   The portal displays my Day 1 schedule, including times and locations.
# *   **Story ID 1 (High):** As a new manager, I want an automated workflow to assign and track pre-boarding tasks so that I can ensure my new hire has everything they need on Day 1 without manual follow-up.
#     *   **Acceptance Criteria:**
#         *   When a new hire is added, tasks are automatically created in Jira for IT, HR, and the hiring manager.
#         *   I can view the status (To Do, In Progress, Done) of all pre-boarding tasks for my new hire.
#         *   The system sends reminders for overdue tasks.
# *   **Story ID 4 (High):** As a new hire, I want a dynamic agenda for my first day integrated with my calendar so that I know exactly where to be and what to expect, which reduces my anxiety.
#     *   **Acceptance Criteria:**
#         *   My Day 1 schedule is automatically added to my Google Calendar.
#         *   Each calendar event includes a meeting link or physical location.
#         *   The agenda includes objectives for key meetings.
#
# ---
# **Epic 2: Connection & Belonging**
# *Fostering a sense of community and inclusion from the very beginning.*
#
# *   **Story ID 6 (High):** As a new sales rep, I want to be automatically connected with a peer 'buddy' so that I have a go-to person for informal questions and can start building my network.
#     *   **Acceptance Criteria:**
#         *   The system assigns me a buddy from my department.
#         *   An automated Slack DM is sent to both me and my buddy with an introduction.
#         *   The introductory message includes conversation starters and a prompt to schedule a coffee chat.
# *   **Story ID 3 (Medium):** As a remote engineer, I want to see profiles of my new team members before I start so that I can put faces to names and make virtual introductions less awkward.
#     *   **Acceptance Criteria:**
#         *   The showcase displays photos, roles, and a fun fact for each team member.
#         *   I can click on a team member's profile to see a link to their LinkedIn.
#         *   The page clearly identifies my direct manager and assigned buddy.
# *   **Story ID 5 (Medium):** As a remote engineer, I want an automated welcome announcement posted in a public channel so that the wider company knows I've joined and I feel included from day one.
#     *   **Acceptance Criteria:**
#         *   A welcome message is automatically posted to a designated Slack channel on the morning of my start date.
#         *   The message includes my name, photo, role, and a fun fact I provided.
#         *   My manager is tagged in the welcome post.
#
# ---
# **Epic 3: Ramp-up & Productivity**
# *Providing clear direction and resources to help new hires become effective quickly.*
#
# *   **Story ID 7 (High):** As a remote engineer, I want a 90-day learning pathway specific to my role so that I have a clear, actionable roadmap to understand the codebase and become productive quickly.
#     *   **Acceptance Criteria:**
#         *   My pathway is pre-populated with tasks and learning modules for a Backend Engineer.
#         *   I can check off items as I complete them and see my overall progress.
#         *   The pathway includes links to key technical documentation and our LMS.
# *   **Story ID 9 (High):** As a remote engineer, I want a centralized, searchable knowledge hub so that I can independently find answers to my questions about technical standards and internal tools.
#     *   **Acceptance Criteria:**
#         *   The hub has a prominent search bar that returns relevant documents and FAQs.
#         *   Content is categorized by department (e.g., Engineering, IT, HR).
#         *   The hub contains essential documents like 'How to set up your dev environment'.
# *   **Story ID 11 (High):** As a manager, I want a simple framework to collaboratively set and track 30/60/90-day goals with my new hire so that we can align on expectations and have a clear definition of success.
#     *   **Acceptance Criteria:**
#         *   I can create 3-5 key goals for the onboarding period within the tool.
#         *   Both the new hire and I can add comments to track progress on each goal.
#         *   Goals can be marked as 'On Track', 'At Risk', or 'Complete'.
# *   **Story ID 8 (Medium):** As a new sales rep, I want a searchable, interactive org chart so that I can quickly figure out who's who and find the right person to talk to in other departments.
#     *   **Acceptance Criteria:**
#         *   I can search for employees by name, title, or team.
#         *   Clicking on a profile shows their manager, direct reports, and team responsibilities.
#         *   The chart visually represents the company's reporting structure.
# *   **Story ID 10 (Low):** As a new hire, I want a searchable wiki of company acronyms so that I can understand internal jargon and get up to speed faster in meetings.
#     *   **Acceptance Criteria:**
#         *   I can search for an acronym and see its full name and definition.
#         *   The wiki is user-editable, allowing employees to add new terms.
#         *   The wiki is linked from the Centralized Knowledge Hub.
#
# ---
# **Epic 4: Manager & Admin Experience**
# *Equipping managers with the tools to effectively guide their new hires.*
#
# *   **Story ID 12 (High):** As a manager, I want a single dashboard to track the progress of all my new hires so that I can efficiently support them and identify potential issues early.
#     *   **Acceptance Criteria:**
#         *   The dashboard lists all my current new hires.
#         *   For each new hire, I can see their percentage completion of their learning pathway.
#         *   The dashboard flags upcoming or overdue check-ins.
#
# ---
# **Epic 5: Feedback & Improvement**
# *Creating a continuous feedback loop to improve the onboarding process itself.*
#
# *   **Story ID 13 (Medium):** As a new hire, I want to receive short, automated surveys so that I can provide confidential feedback on my onboarding experience and feel that my voice is heard.
#     *   **Acceptance Criteria:**
#         *   A short survey is automatically sent to me via Slack at the 30, 60, and 90-day marks.
#         *   The survey contains 2-3 questions about my experience.
#         *   My responses are submitted anonymously to HR for process improvement.
# *   **Story ID 14 (Low):** As a remote engineer, I want a simple way for my manager and peers to give me public 'shout-outs' so that my contributions are visible and I feel valued early on.
#     *   **Acceptance Criteria:**
#         *   Users can give a shout-out using a Slack command (e.g., /shoutout @Priya for fixing that bug).
#         *   Shout-outs are posted in a public 'wins' channel.
#         *   All shout-outs I receive are collected on my profile within the onboarding tool.
#
# ## 5. Non-Functional Requirements (NFRs)
# *The qualities of the system. These are just as important as the functional requirements.*
#
# - **Performance:** The application must load in under 3 seconds on a standard corporate network connection.
# - **Security:** All data must be encrypted in transit and at rest. The system must comply with company SSO policies.
# - **Accessibility:** The user interface must be compliant with WCAG 2.1 AA standards.
# - **Scalability:** The system must support up to 500 concurrent users during peak onboarding seasons.
#
# ## 6. Release Plan & Milestones
# *A high-level timeline for delivery.*
#
# - **Version 1.0 (MVP):** [Target Date: End of Q1] - Core experience focusing on all **High** priority features. This includes the automated task workflow, personalized new hire portal, dynamic calendar agenda, buddy connector, role-based learning pathways, centralized knowledge hub, 30/60/90-day goal tracker, and the manager dashboard.
# - **Version 1.1:** [Target Date: End of Q2] - Enhanced connection and feedback features. This includes the **Medium** priority items: meet the team showcase, automated welcome announcements, interactive org chart, and new hire pulse surveys.
# - **Version 2.0:** [Target Date: End of Q3] - Culture and engagement add-ons. This will incorporate the **Low** priority items: company acronym wiki and the early wins recognition feed.
#
# ## 7. Out of Scope & Future Considerations
# *What this product is **not**. This section is critical for managing expectations and preventing scope creep.*
#
# **7.1. Out of Scope for V1.0:**
# - Direct integration with third-party HR payroll systems.
# - A native mobile application (the web app will be mobile-responsive).
# - Advanced, customizable analytics dashboard for managers.
# - User-generated content for learning pathways.
#
# **7.2. Future Work:**
# - Deeper integration with the corporate Learning Management System (LMS) for course tracking.
# - AI-powered personalized learning recommendations.
# - Gamification elements to encourage engagement and completion.
# - Onboarding journey templates for different departments and roles.
#
# ## 8. Appendix & Open Questions
# *A place to track dependencies, assumptions, and questions that need answers.*
#
# - **Open Question:** Who is the designated owner for creating and maintaining the role-based learning pathways?
# - **Open Question:** What is the source of truth for the data that will power the interactive org chart?
# - **Open Question:** What is the moderation policy for the user-editable company acronym wiki?
# - **Dependency:** The final UI/UX design mockups are required from the Design team by [Date].
# - **Dependency:** The Engineering team needs access to the Jira and Google Calendar APIs by [Date] to begin technical discovery.

# %% [markdown]
# ### Challenge 3 (Advanced): Programmatic Validation with Pydantic
#
# **Task:** We will now create a Pydantic model to represent the structure of our PRD. This allows us to programmatically validate any PRD, ensuring it meets our standards before it's accepted as a formal artifact.
#
# **Instructions:**
# 1.  Prompt the LLM to generate a Pydantic model that reflects the structure of the `prd_template.md`. The model should have fields for each major section (e.g., `introduction: str`, `user_personas: List[str]`, `user_stories: List[Dict]`).
# 2.  Save this generated model code to a file named `app/validation_models/prd_model.py`.
# 3.  While we won't write the full validation script in this lab, generating the Pydantic model itself is the key advanced step. It creates a reusable, code-based standard for our documentation.
#
# **Expected Quality:** A Python file containing a valid Pydantic model that can be used in the future to validate PRD documents automatically. This represents a shift from manual document review to automated governance.

# %%
# TODO: Write a prompt to generate a Pydantic model for the PRD.
# Tip: Be specific. Tell the LLM to create a class named 'ProductRequirementsDocument' and to use appropriate types from Python's 'typing' library.
pydantic_model_prompt = f"""
Create a Pydantic model named 'ProductRequirementsDocument' that represents the structure of the following Product Requirements Document (PRD). Use appropriate types from Python's 'typing' library.
PRD Content:{prd_template_content}
"""

print("--- Generating Pydantic Model for PRD ---")
if prd_template_content:
    pydantic_model_code = get_completion(pydantic_model_prompt, client, model_name, api_provider)
    
    # Clean up the code if it's wrapped in markdown fences
    if '```' in pydantic_model_code:
        pydantic_model_code = pydantic_model_code.split('```')[1].lstrip('python').strip()
    
    print("\n--- Generated Pydantic Model ---")
    print(pydantic_model_code)

    # Save the generated Pydantic model code to a file.
    model_path = "app/validation_models/prd_model.py"
    save_artifact(pydantic_model_code, model_path, overwrite=True)
else:
    print("Skipping Pydantic model generation because template is missing.")

# Finally, save the completed PRD from the intermediate challenge
if prd_from_template_output:
    save_artifact(prd_from_template_output, "day1_prd.md")
# Out:
# --- Generating Pydantic Model for PRD ---
#
# --- Generated Pydantic Model ---
# import datetime
# from enum import Enum
# from typing import List, Optional
#
# from pydantic import BaseModel, Field
#
#
# # --- Enums and Helper Models ---
#
# class DocumentStatus(str, Enum):
#     """Enumeration for the PRD's status."""
#     DRAFT = "Draft"
#     IN_REVIEW = "In Review"
#     APPROVED = "Approved"
#
#
# class ProblemDefinition(BaseModel):
#     """Defines the problem the product aims to solve."""
#     problem_statement: str = Field(..., description="A clear and concise description of the primary problem.")
#     user_personas: List[str] = Field(..., description="A list of key user personas affected by the problem.")
#
#
# class GoalMetric(BaseModel):
#     """Represents a single goal with its corresponding KPI and target."""
#     goal: str = Field(..., description="The high-level objective.")
#     kpi: str = Field(..., description="The Key Performance Indicator to measure progress towards the goal.")
#     target: str = Field(..., description="The specific, measurable target for the KPI.")
#
#
# class UserStory(BaseModel):
#     """Models a single user story with its acceptance criteria."""
#     id: str = Field(..., description="A unique identifier for the story (e.g., '1.1').")
#     story: str = Field(..., description="The user story in the format 'As a [persona], I want [action], so that [benefit].'")
#     acceptance_criteria: List[str] = Field(..., description="A list of conditions that must be met for the story to be considered complete.")
#
#
# class Epic(BaseModel):
#     """A collection of related user stories that represent a larger feature."""
#     title: str = Field(..., description="The title of the epic (e.g., 'User Authentication').")
#     user_stories: List[UserStory]
#
#
# class NonFunctionalRequirements(BaseModel):
#     """Defines the quality attributes and constraints of the system."""
#     performance: Optional[str] = Field(None, description="Requirements for system speed and responsiveness.")
#     security: Optional[str] = Field(None, description="Requirements for data protection and access control.")
#     accessibility: Optional[str] = Field(None, description="Standards for usability by people with disabilities (e.g., WCAG).")
#     scalability: Optional[str] = Field(None, description="The system's ability to handle a growing amount of work.")
#
#
# class Milestone(BaseModel):
#     """A significant point in the project's timeline, typically a release."""
#     version: str = Field(..., description="The version name or number (e.g., 'Version 1.0 (MVP)').")
#     target_date: datetime.date = Field(..., description="The planned delivery date for the milestone.")
#     description: str = Field(..., description="A brief summary of the features included in this milestone.")
#
#
# class Scope(BaseModel):
#     """Clarifies what is included and excluded from a release, and what is planned for the future."""
#     out_of_scope_for_v1: List[str] = Field(..., description="Features explicitly not being built in the initial version.")
#     future_work: List[str] = Field(..., description="Potential features or integrations to be considered for future releases.")
#
#
# class Appendix(BaseModel):
#     """A section for tracking open questions, dependencies, and other notes."""
#     open_questions: List[str] = Field(..., description="Questions that need to be answered to move forward.")
#     dependencies: List[str] = Field(..., description="External factors or deliverables the project relies on.")
#
#
# # --- Main Product Requirements Document Model ---
#
# class ProductRequirementsDocument(BaseModel):
#     """
#     A Pydantic model representing a complete Product Requirements Document (PRD).
#     """
#     product_name: str = Field(..., description="The name of the product this PRD is for.")
#     status: DocumentStatus = Field(..., description="The current status of the document.")
#     author: str = Field(..., description="The person or team who authored the document.")
#     version: float = Field(..., description="The version number of the document.")
#     last_updated: datetime.date = Field(..., description="The date the document was last updated.")
#
#     executive_summary_and_vision: str = Field(
#         ..., description="A high-level overview of the product, its purpose, and its vision for success."
#     )
#     problem: ProblemDefinition = Field(
#         ..., description="Details the pain points, user personas, and scenarios this product addresses."
#     )
#     goals_and_success_metrics: List[GoalMetric] = Field(
#         ..., description="A list of specific, measurable outcomes used to define success."
#     )
#     functional_requirements: List[Epic] = Field(
#         ..., description="The core features of the product, detailed as epics and user stories."
#     )
#     non_functional_requirements: NonFunctionalRequirements = Field(
#         ..., description="The quality attributes of the system, such as performance, security, etc."
#     )
#     release_plan_and_milestones: List[Milestone] = Field(
#         ..., description="A high-level timeline and plan for product delivery."
#     )
#     scope_and_future_considerations: Scope = Field(
#         ..., description="Defines what is out of scope for the current release and what may be considered in the future."
#     )
#     appendix_and_open_questions: Appendix = Field(
#         ..., description="A section to track dependencies, assumptions, and unresolved questions."
#     )
#
#     class Config:
#         title = "Product Requirements Document"
#         use_enum_values = True # Ensures the string value of the enum is used
#
#
# # --- Example Usage ---
#
# if __name__ == "__main__":
#     # 1. Create an instance of the PRD model with data from the example document
#     prd_data = {
#         "product_name": "New Hire Onboarding Platform",
#         "status": "Draft",
#         "author": "The Product Team",
#         "version": 1.0,
#         "last_updated": "2023-10-27",
#         "executive_summary_and_vision": "This product is a centralized onboarding platform designed to streamline the new hire experience. We are building it to solve the fragmented and overwhelming process new employees face. The ultimate vision is to accelerate time-to-productivity and foster a sense of belonging from day one.",
#         "problem": {
#             "problem_statement": "New hires currently face a fragmented and overwhelming onboarding experience, leading to decreased initial productivity and a high volume of repetitive questions to HR and managers.",
#             "user_personas": [
#                 "Persona 1: The New Hire",
#                 "Persona 2: The Hiring Manager",
#                 "Persona 3: The HR Coordinator"
#             ]
#         },
#         "goals_and_success_metrics": [
#             {"goal": "Improve New Hire Efficiency", "kpi": "Reduce time-to-first-contribution", "target": "Decrease by 20% in Q1"},
#             {"goal": "Reduce Support Load", "kpi": "Decrease repetitive questions to HR", "target": "30% reduction in support tickets"},
#             {"goal": "Increase Engagement", "kpi": "Onboarding completion rate", "target": "Achieve 95% completion rate"}
#         ],
#         "functional_requirements": [
#             {
#                 "title": "User Authentication",
#                 "user_stories": [
#                     {
#                         "id": "1.1",
#                         "story": "As a New Hire, I want to log in with my company credentials, so that I can access the onboarding platform securely.",
#                         "acceptance_criteria": [
#                             "Given I am on the login page, when I enter my valid SSO credentials, then I am redirected to my personal dashboard.",
#                             "Given I am on the login page, when I enter invalid credentials, then I see a clear error message."
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "non_functional_requirements": {
#             "performance": "The application must load in under 3 seconds on a standard corporate network connection.",
#             "security": "All data must be encrypted in transit and at rest. The system must comply with company SSO policies.",
#             "accessibility": "The user interface must be compliant with WCAG 2.1 AA standards.",
#             "scalability": "The system must support up to 500 concurrent users during peak onboarding seasons."
#         },
#         "release_plan_and_milestones": [
#             {"version": "Version 1.0 (MVP)", "target_date": "2024-01-31", "description": "Core features including user login, task checklist, and document repository."},
#             {"version": "Version 1.1", "target_date": "2024-03-15", "description": "Mentorship connection and team introduction features."},
#             {"version": "Version 2.0", "target_date": "2024-06-30", "description": "Full social engagement and gamification elements."}
#         ],
#         "scope_and_future_considerations": {
#             "out_of_scope_for_v1": [
#                 "Direct integration with third-party HR payroll systems.",
#                 "A native mobile application (the web app will be mobile-responsive).",
#                 "Advanced analytics dashboard for managers."
#             ],
#             "future_work": [
#                 "Integration with the corporate Learning Management System (LMS).",
#                 "AI-powered personalized learning paths for new hires."
#             ]
#         },
#         "appendix_and_open_questions": {
#             "open_questions": ["Which team will be responsible for maintaining the content in the document repository?"],
#             "dependencies": ["The final UI design mockups are required from the Design team by 2023-11-15."]
#         }
#     }
#
#     try:
#         prd_document = ProductRequirementsDocument(**prd_data)
#
#         # 2. Print the validated data as a JSON object
#         print(prd_document.json(indent=2))
#
#         # 3. Access a specific field
#         print("\n--- Accessing a specific field ---")
#         print(f"Product Vision: {prd_document.executive_summary_and_vision}")
#         print(f"First Goal: {prd_document.goals_and_success_metrics[0].goal}")
#
#     except Exception as e:
#         print(f"An error occurred during model validation: {e}")
# ---------------------------------------------------------------------------
# ArtifactError                             Traceback (most recent call last)
# Cell In[4], line 21
#      19     # Save the generated Pydantic model code to a file.
#      20     model_path = "app/validation_models/prd_model.py"
# ---> 21     save_artifact(pydantic_model_code, model_path)
#      22 else:
#      23     print("Skipping Pydantic model generation because template is missing.")
#
# File c:\Workspace\AG-AISOFTDEV\utils\artifacts.py:169, in save_artifact(content, filename, base_dir, subdir, overwrite, encoding)
#     167 path.parent.mkdir(parents=True, exist_ok=True)
#     168 if path.exists() and not overwrite:
# --> 169     raise ArtifactError(
#     170         f"Artifact already exists: {path}. Pass overwrite=True to replace."
#     171     )
#     173 tmp = path.with_suffix(path.suffix + ".tmp")
#     174 try:
#
# ArtifactError: Artifact already exists: C:\Workspace\AG-AISOFTDEV\artifacts\app\validation_models\prd_model.py. Pass overwrite=True to replace.

# %% [markdown]
# ## Lab Conclusion
#
# Excellent work! You have now taken the structured user stories from the first lab and synthesized them into a formal Product Requirements Document. You also created a Pydantic model to enforce the structure of this document, introducing automated governance into your workflow. The `day1_prd.md` artifact will be the primary input for Day 2, where we will begin designing our system's architecture and database.
#
# > **Key Takeaway:** Using an LLM to populate a pre-defined template is a powerful pattern for creating consistent, high-quality documentation at scale. It combines the LLM's language skills with your required structure.
